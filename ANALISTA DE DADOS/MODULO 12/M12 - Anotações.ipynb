# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Data Wrangling I
# Caderno de **Aula**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>DataFrame Pandas;</li>
#   <li>Selecão e Filtros;</li>
#   <li>Inserção, Deleção e Atualização.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Aulas**

# %% [markdown]
# ## 0\. Estruturas de dados

# %% [markdown]
# *   **Não estruturado**: texto, imagem, aúdio, etc.
# *   **Semi estruturado**: html, json, etc.
# *   <font color='red'>**Estruturado**</font>: tabelas, planilhas, etc.

# %% [markdown]
# ## 1\. DataFrame Pandas

# %% [markdown]
# ### **1.1. Pacote Pandas**

# %% [markdown]
# Pacote Python para manipulação de dados (talvez o mais utilizado). A documentação pode ser encontrada neste [link](https://pandas.pydata.org/docs/). A abstração base do pandas é o DataFrame, uma estrutura de dados Python de duas dimensões utilizado para representar tabelas.

# %% [markdown]
# **Exemplo**: Criar um DataFrame Pandas a partir de um dicionário Python.

# %%
#Definindo dicionario
transacoes = dict(

    id=[571, 572, 573],
    data=['19-01-2021', '19-01-2021', '23-01-2021'],
    valor=[371.30, 57.19, 101.21],
    categoria=['supermercado', 'farmacia', 'outros']
)

# %%
#Importando biblioteca
import pandas as pd

#Gerar data frame apartir de um dicionario
#Nova variavel (transacoes_df) metodo - pd.dataframa e a variavel do dicionario (transacoes)
# _df variaveis que tem data frame
transacoes_df = pd.DataFrame(transacoes)

# %%
transacoes_df
# Out:
#     id        data   valor     categoria
# 0  571  19-01-2021  371.30  supermercado
# 1  572  19-01-2021   57.19      farmacia
# 2  573  23-01-2021  101.21        outros

# %%
type(transacoes_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# *   Atributos

# %%
#identificador de coluna
#Trazer o nome das colunas
transacoes_df.columns
# Out:
# Index(['id', 'data', 'valor', 'categoria'], dtype='object')

# %%
#Tipo do dado que esta em cada coluna
#object = string
transacoes_df.dtypes
# Out:
# id             int64
# data          object
# valor        float64
# categoria     object
# dtype: object

# %%
#identificador de linha
transacoes_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#forma do nosso data frame
#linhas e colunas
transacoes_df.shape
# Out:
# (3, 4)

# %% [markdown]
# *   Métodos

# %%
#trazer as 5 primeiras linhas do data frame de cima para baixo
transacoes_df.head(n=5)
# Out:
#     id        data   valor     categoria
# 0  571  19-01-2021  371.30  supermercado
# 1  572  19-01-2021   57.19      farmacia
# 2  573  23-01-2021  101.21        outros

# %%
#trazer as 5 primeiras linhas do data frame de baixo para cima
# tambem tem o parametro n=
transacoes_df.tail()
# Out:
#     id        data   valor     categoria
# 0  571  19-01-2021  371.30  supermercado
# 1  572  19-01-2021   57.19      farmacia
# 2  573  23-01-2021  101.21        outros

# %%
#Compilado do dataframe
transacoes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3 non-null      int64
#  1   data       3 non-null      object
#  2   valor      3 non-null      float64
#  3   categoria  3 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
# colunas numéricas
# T - transformar linhas em colunas
# metrica dos numeros

transacoes_df[['id', 'valor']].describe().T
# Out:
#        count        mean         std     min    25%     50%      75%    max
# id       3.0  572.000000    1.000000  571.00  571.5  572.00  572.500  573.0
# valor    3.0  176.566667  170.074229   57.19   79.2  101.21  236.255  371.3

# %%
# colunas categóricas
# dados que nao sao numericos
transacoes_df[['data', 'categoria']].describe().T
# Out:
#           count unique           top freq
# data          3      2    19-01-2021    2
# categoria     3      3  supermercado    1

# %% [markdown]
# **Exemplo**: Criar um DataFrame Pandas a partir de um arquivo csv.

# %%
#criar arquivo csv metodo writefile

# %%writefile github.csv
ranking;project;language;stars;stars_today;forks
1;plow;go;1304;574;38
2;n8n;typescript;15668;280;1370
3;slides;go;3218;265;80
4;defi-developer-road-map;;636;247;49
5;pytorch-image-models;python;11065;101;1646
6;javascript-algorithms;javascript;110768;248;18331
7;paddleclas;python;1429;283;323
8;reddit_sentiment_trader;python;369;71;60
9;augly;python;2849;393;99
10;self-taught-guide-to-cloud-computing;;863;179;84
# Out:
# Overwriting github.csv

# %%
#Importar a biblioteca
import pandas as pd

#variavel datadrame " github_df "
#read_csv ler arquivo csv
# separador do arquivo csv " ; "
github_df = pd.read_csv('github.csv', sep=';')

# %%
#NaN not and number
github_df
# Out:
#    ranking                               project    language   stars  \
# 0        1                                  plow          go    1304
# 1        2                                   n8n  typescript   15668
# 2        3                                slides          go    3218
# 3        4               defi-developer-road-map         NaN     636
# 4        5                  pytorch-image-models      python   11065
# 5        6                 javascript-algorithms  javascript  110768
# 6        7                            paddleclas      python    1429
# 7        8               reddit_sentiment_trader      python     369
# 8        9                                 augly      python    2849
# 9       10  self-taught-guide-to-cloud-computing         NaN     863
#
#    stars_today  forks
# 0          574     38
# 1          280   1370
# 2          265     80
# 3          247     49
# 4          101   1646
# 5          248  18331
# 6          283    323
# 7           71     60
# 8          393     99
# 9          179     84

# %%
type(github_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# *   Atributos

# %%
github_df.columns
# Out:
# Index(['ranking', 'project', 'language', 'stars', 'stars_today', 'forks'], dtype='object')

# %%
github_df.dtypes
# Out:
# ranking         int64
# project        object
# language       object
# stars           int64
# stars_today     int64
# forks           int64
# dtype: object

# %%
github_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
github_df.shape
# Out:
# (10, 6)

# %% [markdown]
# *   Métodos

# %%
github_df.head()
# Out:
#    ranking                  project    language  stars  stars_today  forks
# 0        1                     plow          go   1304          574     38
# 1        2                      n8n  typescript  15668          280   1370
# 2        3                   slides          go   3218          265     80
# 3        4  defi-developer-road-map         NaN    636          247     49
# 4        5     pytorch-image-models      python  11065          101   1646

# %%
github_df.tail()
# Out:
#    ranking                               project    language   stars  \
# 5        6                 javascript-algorithms  javascript  110768
# 6        7                            paddleclas      python    1429
# 7        8               reddit_sentiment_trader      python     369
# 8        9                                 augly      python    2849
# 9       10  self-taught-guide-to-cloud-computing         NaN     863
#
#    stars_today  forks
# 5          248  18331
# 6          283    323
# 7           71     60
# 8          393     99
# 9          179     84

# %%
github_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ranking      10 non-null     int64
#  1   project      10 non-null     object
#  2   language     8 non-null      object
#  3   stars        10 non-null     int64
#  4   stars_today  10 non-null     int64
#  5   forks        10 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 608.0+ bytes

# %%
github_df[['project', 'language']].describe().T # colunas categóricas
# Out:
#          count unique     top freq
# project     10     10    plow    1
# language     8      4  python    4

# %%
github_df[['ranking', 'stars', 'stars_today', 'forks']].describe().T # colunas numéricas
# Out:
#              count     mean           std    min     25%     50%      75%  \
# ranking       10.0      5.5      3.027650    1.0    3.25     5.5     7.75
# stars         10.0  14816.9  34100.448392  369.0  973.25  2139.0  9103.25
# stars_today   10.0    264.1    143.351510   71.0  196.00   256.5   282.25
# forks         10.0   2208.0   5695.945615   38.0   65.00    91.5  1108.25
#
#                   max
# ranking          10.0
# stars        110768.0
# stars_today     574.0
# forks         18331.0

# %% [markdown]
# ### **1.2. Anatomia de um DataFrame**

# %% [markdown]
# *   **Série**: `Coluna` de um DataFrame;
# *   **Índice**: Indentificador de uma `linha` de um DataFrame.

# %%
#DataFrama - estrutura de dados similar a uma lista e um dicionario python
#dataframe dividido em linhas e colinas
# Coluna = Serie
# Indice = Linha

github_df
# Out:
#    ranking                               project    language   stars  \
# 0        1                                  plow          go    1304
# 1        2                                   n8n  typescript   15668
# 2        3                                slides          go    3218
# 3        4               defi-developer-road-map         NaN     636
# 4        5                  pytorch-image-models      python   11065
# 5        6                 javascript-algorithms  javascript  110768
# 6        7                            paddleclas      python    1429
# 7        8               reddit_sentiment_trader      python     369
# 8        9                                 augly      python    2849
# 9       10  self-taught-guide-to-cloud-computing         NaN     863
#
#    stars_today  forks
# 0          574     38
# 1          280   1370
# 2          265     80
# 3          247     49
# 4          101   1646
# 5          248  18331
# 6          283    323
# 7           71     60
# 8          393     99
# 9          179     84

# %% [markdown]
# ## 2\. Seleção e Filtros

# %% [markdown]
# ### **2.1. Série**

# %% [markdown]
# Uma **série** é uma **coluna** de um **dataframe**. Para selecionar uma coluna utilizamos a seguinte notação (similiar a indexação de listas Python):
#
# ```python
# serie = dataframe['<nome-da-coluna>']
# ```
#
# **Nota**: Repare no uso das chaves simples `[ ]`.

# %% [markdown]
# *   **Exemplo**: Coluna linguagem de programação do dataframe `github_df`:

# %%
linguagem_serie = github_df['language']

# %%
linguagem_serie
# Out:
# 0            go
# 1    typescript
# 2            go
# 3           NaN
# 4        python
# 5    javascript
# 6        python
# 7        python
# 8        python
# 9           NaN
# Name: language, dtype: object

# %%
type(linguagem_serie)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### 2.1.1 Seleção

# %% [markdown]
# *   **Exemplo**: Indexação simples com método `loc` (similar a lista Python):

# %%
# extrair valor expecifico Pandas
# .loc = localizar
# [ ] <- passar o index = a linha
top_1_linguagem = linguagem_serie.loc[0]

# %%
top_1_linguagem
# Out:
# 'go'

# %%
type(top_1_linguagem)
# Out:
# str

# %% [markdown]
# *   **Exemplo**: Fatiamento ou *slicing* com método `loc` (similar a lista Python):

# %%
#definir o range da lista [ ]
top_5_linguagem = linguagem_serie.loc[0:5]

# %%
top_5_linguagem
# Out:
# 0            go
# 1    typescript
# 2            go
# 3           NaN
# 4        python
# 5    javascript
# Name: language, dtype: object

# %%
type(top_5_linguagem)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### 2.1.2 Filtros

# %% [markdown]
# *   **Exemplo**: Filtro funcional:

# %%
# linguagem_serie - é a serie (coluna) completa
# funcao lambda ca serie linguagem
# se linguagem for == a python = extrair
linguagem_serie[lambda linguagem: linguagem == 'python']
# Out:
# 4    python
# 6    python
# 7    python
# 8    python
# Name: language, dtype: object

# %% [markdown]
# *   **Exemplo**: Filtro funcional com novos índices:

# %%
# linguagem_serie - é a serie (coluna) completa
# funcao lambda ca serie linguagem
# se linguagem for == a python = extrair
# .reset_index - serve para reiniciar o index
linguagem_serie[lambda linguagem: linguagem == 'python'].reset_index(drop=True)
# Out:
# 0    python
# 1    python
# 2    python
# 3    python
# Name: language, dtype: object

# %% [markdown]
# ### **2.2. DataFrame**

# %% [markdown]
# Um **conjunto** de **colunas** ou **séries** é um novo **dataframe**. Para selecionar um conjunto de colunas utilizamos a seguinte notação:
#
# ```python
# novo_dataframe = dataframe[['<nome-da-coluna-a>', '<nome-da-coluna-b>', ...]]
# ```
#
# **Nota**: Repare no uso das chaves duplas `[[ ]]`.

# %% [markdown]
# *   **Exemplo**: Colunas ranking e linguagem de programação do dataframe `github_df`:

# %%
ranking_linguagem_df = github_df[['ranking', 'language']]

# %%
ranking_linguagem_df
# Out:
#    ranking    language
# 0        1          go
# 1        2  typescript
# 2        3          go
# 3        4         NaN
# 4        5      python
# 5        6  javascript
# 6        7      python
# 7        8      python
# 8        9      python
# 9       10         NaN

# %%
type(ranking_linguagem_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 2.2.1 Seleção

# %% [markdown]
# *   **Exemplo**: Indexação simples (linha) com método `loc` (similar a lista Python):

# %%
# pegar o index( linha ) completa
top_1_linguagem = ranking_linguagem_df.loc[0]

# %%
top_1_linguagem
# Out:
# ranking      1
# language    go
# Name: 0, dtype: object

# %%
type(top_1_linguagem)
# Out:
# pandas.core.series.Series

# %% [markdown]
# *   **Exemplo**: Indexação simples (linha e coluna) com método `loc` (similar a lista Python):

# %%
top_1_linguagem = github_df.loc[0, ['ranking', 'language']]

# %%
top_1_linguagem
# Out:
# ranking      1
# language    go
# Name: 0, dtype: object

# %%
type(top_1_linguagem)
# Out:
# pandas.core.series.Series

# %% [markdown]
# *   **Exemplo**: Fatiamento ou *slicing* (linhas) com método `loc` (similar a lista Python):

# %%
top_5_ranking_linguagem = ranking_linguagem_df.loc[0:5]

# %%
top_5_ranking_linguagem
# Out:
#    ranking    language
# 0        1          go
# 1        2  typescript
# 2        3          go
# 3        4         NaN
# 4        5      python
# 5        6  javascript

# %%
type(top_5_ranking_linguagem)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# *   **Exemplo**: Fatiamento ou *slicing* (linhas e colunas) com método `loc` (similar a lista Python):

# %%
top_5_ranking_linguagem = github_df.loc[0:5, ['ranking', 'language']]

# %%
top_5_ranking_linguagem
# Out:
#    ranking    language
# 0        1          go
# 1        2  typescript
# 2        3          go
# 3        4         NaN
# 4        5      python
# 5        6  javascript

# %%
type(top_5_ranking_linguagem)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 2.2.2 Filtros

# %% [markdown]
# *   **Exemplo**: Filtro com o método `query`:

# %%
#ranking_linguagem_df = dataframe
#metodo .query
# ( coluna == conteudo )

ranking_linguagem_df.query('language == "python"')
# Out:
#    ranking language
# 4        5   python
# 6        7   python
# 7        8   python
# 8        9   python

# %%
ranking_linguagem_df.query('language == "python" & ranking > 5')
# Out:
#    ranking language
# 6        7   python
# 7        8   python
# 8        9   python

# %%
ranking_linguagem_df.query('language == "python" | language == "go"')
# Out:
#    ranking language
# 0        1       go
# 2        3       go
# 4        5   python
# 6        7   python
# 7        8   python
# 8        9   python

# %% [markdown]
# ## 3\. Inserção, Deleção e Atualização

# %% [markdown]
# ### **3.1. Série**

# %% [markdown]
# #### 3.1.1 Inserção

# %% [markdown]
# *   **Exemplo**: Adição de elementos com o método `append`:

# %%
#serie (coluna) linguagem_serie
# metodo .append inserir algo
# nova serie ( coluna )
# com uma lista ([ ])
# parametro .append ignore_index

linguagem_serie.append(pd.Series(['java', 'python']), ignore_index=True)
# Out:
# <ipython-input-228-d7d4232c7423>:7: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   linguagem_serie.append(pd.Series(['java', 'python']), ignore_index=True)
# 0             go
# 1     typescript
# 2             go
# 3            NaN
# 4         python
# 5     javascript
# 6         python
# 7         python
# 8         python
# 9            NaN
# 10          java
# 11        python
# dtype: object

# %%
linguagem_serie
# Out:
# 0            go
# 1    typescript
# 2            go
# 3           NaN
# 4        python
# 5    javascript
# 6        python
# 7        python
# 8        python
# 9           NaN
# Name: language, dtype: object

# %%
linguagem_serie = linguagem_serie.append(pd.Series('java'), ignore_index=True)
# Out:
# <ipython-input-230-6446adde80bc>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   linguagem_serie = linguagem_serie.append(pd.Series('java'), ignore_index=True)

# %%
linguagem_serie
# Out:
# 0             go
# 1     typescript
# 2             go
# 3            NaN
# 4         python
# 5     javascript
# 6         python
# 7         python
# 8         python
# 9            NaN
# 10          java
# dtype: object

# %% [markdown]
# #### 3.1.2 Deleção

# %% [markdown]
# *   **Exemplo**: Remoção de elementos com filtro funcional:

# %%
linguagem_serie[lambda linguagem: linguagem != 'python']
# Out:
# 0             go
# 1     typescript
# 2             go
# 3            NaN
# 5     javascript
# 9            NaN
# 10          java
# dtype: object

# %% [markdown]
# #### 3.1.3 Atualização

# %% [markdown]
# *   **Exemplo**: Atualização de elementos com indexação simples:

# %%
linguagem_serie.loc[0] = 'Go'

# %%
linguagem_serie
# Out:
# 0             Go
# 1     typescript
# 2             go
# 3            NaN
# 4         python
# 5     javascript
# 6         python
# 7         python
# 8         python
# 9            NaN
# 10          java
# dtype: object

# %% [markdown]
# *   **Exemplo**: Atualização de elementos com fatiamento ou *slicing*:

# %%
linguagem_serie.loc[0:2] = pd.Series(['Go', 'Typescript', 'Go'])

# %%
linguagem_serie
# Out:
# 0             Go
# 1     Typescript
# 2             Go
# 3            NaN
# 4         python
# 5     javascript
# 6         python
# 7         python
# 8         python
# 9            NaN
# 10          java
# dtype: object

# %% [markdown]
# *   **Exemplo**: Atualização de elementos com filtro funcional:

# %%
linguagem_serie[lambda linguagem: linguagem == 'python'] = 'Python'

# %%
linguagem_serie
# Out:
# 0             Go
# 1     Typescript
# 2             Go
# 3            NaN
# 4         Python
# 5     javascript
# 6         Python
# 7         Python
# 8         Python
# 9            NaN
# 10          java
# dtype: object

# %% [markdown]
# ### **3.2. DataFrame**

# %% [markdown]
# #### 3.1.1 Inserção

# %% [markdown]
# *   **Exemplo**: Adição de linhas com o método `append`:

# %%
#criar um dicionario - " projeto "
# Chaves do dicionario vao ser as chaves do dataframe
# os valores vao ser listas

projeto = dict(ranking=[11], project=['signoz'], language=['typescript'], stars=[2651], stars_today=[491], forks=[115])

# %%
github_df.append(pd.DataFrame(projeto), ignore_index=True)
# Out:
# <ipython-input-240-da2edc10888a>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   github_df.append(pd.DataFrame(projeto), ignore_index=True)
#     ranking                               project    language   stars  \
# 0         1                                  plow          go    1304
# 1         2                                   n8n  typescript   15668
# 2         3                                slides          go    3218
# 3         4               defi-developer-road-map         NaN     636
# 4         5                  pytorch-image-models      python   11065
# 5         6                 javascript-algorithms  javascript  110768
# 6         7                            paddleclas      python    1429
# 7         8               reddit_sentiment_trader      python     369
# 8         9                                 augly      python    2849
# 9        10  self-taught-guide-to-cloud-computing         NaN     863
# 10       11                                signoz  typescript    2651
#
#     stars_today  forks
# 0           574     38
# 1           280   1370
# 2           265     80
# 3           247     49
# 4           101   1646
# 5           248  18331
# 6           283    323
# 7            71     60
# 8           393     99
# 9           179     84
# 10          491    115

# %%
github_df
# Out:
#    ranking                               project    language   stars  \
# 0        1                                  plow          go    1304
# 1        2                                   n8n  typescript   15668
# 2        3                                slides          go    3218
# 3        4               defi-developer-road-map         NaN     636
# 4        5                  pytorch-image-models      python   11065
# 5        6                 javascript-algorithms  javascript  110768
# 6        7                            paddleclas      python    1429
# 7        8               reddit_sentiment_trader      python     369
# 8        9                                 augly      python    2849
# 9       10  self-taught-guide-to-cloud-computing         NaN     863
#
#    stars_today  forks
# 0          574     38
# 1          280   1370
# 2          265     80
# 3          247     49
# 4          101   1646
# 5          248  18331
# 6          283    323
# 7           71     60
# 8          393     99
# 9          179     84

# %%
github_df = github_df.append(pd.DataFrame(projeto), ignore_index=True)
# Out:
# <ipython-input-242-e848ac48f43a>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   github_df = github_df.append(pd.DataFrame(projeto), ignore_index=True)

# %%
github_df
# Out:
#     ranking                               project    language   stars  \
# 0         1                                  plow          go    1304
# 1         2                                   n8n  typescript   15668
# 2         3                                slides          go    3218
# 3         4               defi-developer-road-map         NaN     636
# 4         5                  pytorch-image-models      python   11065
# 5         6                 javascript-algorithms  javascript  110768
# 6         7                            paddleclas      python    1429
# 7         8               reddit_sentiment_trader      python     369
# 8         9                                 augly      python    2849
# 9        10  self-taught-guide-to-cloud-computing         NaN     863
# 10       11                                signoz  typescript    2651
#
#     stars_today  forks
# 0           574     38
# 1           280   1370
# 2           265     80
# 3           247     49
# 4           101   1646
# 5           248  18331
# 6           283    323
# 7            71     60
# 8           393     99
# 9           179     84
# 10          491    115

# %% [markdown]
# #### 3.1.2 Deleção

# %% [markdown]
# *   **Exemplo**: Remoção de linhas com o método `query`:

# %%
github_df.query('language != "python"')
# Out:
#     ranking                               project    language   stars  \
# 0         1                                  plow          go    1304
# 1         2                                   n8n  typescript   15668
# 2         3                                slides          go    3218
# 3         4               defi-developer-road-map         NaN     636
# 5         6                 javascript-algorithms  javascript  110768
# 9        10  self-taught-guide-to-cloud-computing         NaN     863
# 10       11                                signoz  typescript    2651
#
#     stars_today  forks
# 0           574     38
# 1           280   1370
# 2           265     80
# 3           247     49
# 5           248  18331
# 9           179     84
# 10          491    115

# %% [markdown]
# #### 3.1.3 Atualização

# %% [markdown]
# *   **Exemplo**: Atualização de **um** elemento com o método `loc`:

# %%
github_df.loc[0, 'language'] = 'go'

# %%
github_df
# Out:
#     ranking                               project    language   stars  \
# 0         1                                  plow          go    1304
# 1         2                                   n8n  typescript   15668
# 2         3                                slides          go    3218
# 3         4               defi-developer-road-map         NaN     636
# 4         5                  pytorch-image-models      python   11065
# 5         6                 javascript-algorithms  javascript  110768
# 6         7                            paddleclas      python    1429
# 7         8               reddit_sentiment_trader      python     369
# 8         9                                 augly      python    2849
# 9        10  self-taught-guide-to-cloud-computing         NaN     863
# 10       11                                signoz  typescript    2651
#
#     stars_today  forks
# 0           574     38
# 1           280   1370
# 2           265     80
# 3           247     49
# 4           101   1646
# 5           248  18331
# 6           283    323
# 7            71     60
# 8           393     99
# 9           179     84
# 10          491    115

# %% [markdown]
# *   **Exemplo**: Atualização de **diversos** elementos com o método `apply`:

# %%
github_df['language'] = github_df['language'].apply(lambda linguagem: 'python' if linguagem == 'Python' else linguagem)

# %%
github_df
# Out:
#     ranking                               project    language   stars  \
# 0         1                                  plow          go    1304
# 1         2                                   n8n  typescript   15668
# 2         3                                slides          go    3218
# 3         4               defi-developer-road-map         NaN     636
# 4         5                  pytorch-image-models      python   11065
# 5         6                 javascript-algorithms  javascript  110768
# 6         7                            paddleclas      python    1429
# 7         8               reddit_sentiment_trader      python     369
# 8         9                                 augly      python    2849
# 9        10  self-taught-guide-to-cloud-computing         NaN     863
# 10       11                                signoz  typescript    2651
#
#     stars_today  forks
# 0           574     38
# 1           280   1370
# 2           265     80
# 3           247     49
# 4           101   1646
# 5           248  18331
# 6           283    323
# 7            71     60
# 8           393     99
# 9           179     84
# 10          491    115
